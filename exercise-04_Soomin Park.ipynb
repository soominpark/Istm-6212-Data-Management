# %% [markdown]
# # Exercise 04 - Due Friday, October 21 at 12pm
#
# *Objectives*: Gain experience loading a CSV dataset into a database model you define yourself and using SQL to explore its contents. Explore the data by writing and executing a number of SQL queries using common syntax and functions and describing your findings.
#
# *Grading criteria*: The tasks should all be completed, and questions should all be answered with SQL queries in the space provided, unless a text answer is requested. Results should be correct, according to the embedded tests. The notebook itself should be completely reproducible; from start to finish, another person should be able to use the same code to obtain the same results as yours.  Note that you will receive no more than partial credit if you do not add text/markdown cells explaining your thinking at each major step in each problem.
#
# *Deadline*: Friday, October 21, 12pm. Submit your notebook to Blackboard and push it to your GitHub repository.
#
# ## Setup - obtain data and create database
#
# The US City Open Data Census has data on [restaurant inspections from all over the country](http://us-city.census.okfn.org/dataset/food-safety).  Let's take a look at data from Albuquerque.  *Note*: metadata and other details for this dataset are available at http://data.cabq.gov/business/foodinspections/.
#
# Fyi, to save you a step, I've converted this file into a clean CSV file by using the `dos2unix` command to change its line endings and to switch it to use commas instead of tabs using `csvformat -t inputfile.csv > outputfile.csv`.
#
# First we download the dataset:

# %%
# !wget https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/syllabus-and-schedule/master/exercises/abq-food-inspections-fy2010.csv
# Out:
# --2016-10-24 17:38:44--  https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/syllabus-and-schedule/master/exercises/abq-food-inspections-fy2010.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.32.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.32.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5025226 (4.8M) [text/plain]
# Saving to: ‘abq-food-inspections-fy2010.csv.2’
#
# abq-food-inspection 100%[=====================>]   4.79M  --.-KB/s   in 0.07s
#
# 2016-10-24 17:38:45 (67.9 MB/s) - ‘abq-food-inspections-fy2010.csv.2’ saved [5025226/5025226]

# %% [markdown]
# ## Problem 1 - examine the data (35 points)
#
# Use `csvstat` and other tools as you see fit and observe its contents.  Review the metadata definitions linked to above.  Describe what you see:  What do all the columns mean?  Are there null values?  Which columns interest you the most?  Which columns present some complications or questions you would like to ask?

# %%
# !csvstat abq-food-inspections-fy2010.csv
# Out:
#   1. FACILITY_NAME
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 2615
# 	5 most frequent values:
# 		SMITHS FOOD AND DRUG CENTERS INC:	154
# 		ISOTOPES PARK - OVATIONS:	93
# 		PER EHSII CECELIA GARCIA OOB LA REYNA DEL SUR:	85
# 		ECHO INC:	68
# 		ISLETA AMPHITHEATER:	68
# 	Max length: 77
#   2. FACILITY_KEY
# 	<class 'int'>
# 	Nulls: False
# 	Min: 13
# 	Max: 101482
# 	Sum: 820405773
# 	Mean: 46730.79135338346
# 	Median: 50866.0
# 	Standard Deviation: 32659.794578837962
# 	Unique values: 2835
# 	5 most frequent values:
# 		46323:	93
# 		65863:	85
# 		32817:	68
# 		80949:	68
# 		91825:	66
#   3. SITE_ADDRESS
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 2456
# 	5 most frequent values:
# 		1601 AVENIDA CESAR CHAVEZ SE:	94
# 		644 OLD COORS BLVD SW:	85
# 		8601 CENTRAL AV NE:	77
# 		2200 SUNPORT BLVD SE:	75
# 		5210 CENTRAL AV SE:	73
# 	Max length: 35
#   4. CITY
# 	<class 'str'>
# 	Nulls: False
# 	Values: ALBUQUERQUE
#   5. STATE
# 	<class 'str'>
# 	Nulls: False
# 	Values: NM, 87
#   6. ZIP
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 48
# 	5 most frequent values:
# 		87110:	1996
# 		87108:	1976
# 		87102:	1601
# 		87106:	1568
# 		87109:	1552
# 	Max length: 10
#   7. OWNER_KEY
# 	<class 'int'>
# 	Nulls: False
# 	Min: 11
# 	Max: 87302
# 	Sum: 644760848
# 	Mean: 36725.953975848715
# 	Median: 33747.0
# 	Standard Deviation: 29428.207216739836
# 	Unique values: 1892
# 	5 most frequent values:
# 		1838:	792
# 		3537:	321
# 		1272:	228
# 		36280:	156
# 		80274:	155
#   8. OWNER_NAME
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 1852
# 	5 most frequent values:
# 		APS:	792
# 		SMITHS FOOD AND DRUG CENTERS INC:	321
# 		CIRCLE K STORES INC:	277
# 		ALBERTSONS:	228
# 		WAL MART STORES EAST  LP:	156
# 	Max length: 82
#   9. NATURE_OF_BUSINESS
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 594
# 	5 most frequent values:
# 		RESTAURANT:	4994
# 		FOOD SERVICE:	691
# 		GROCERY:	618
# 		BAR/RESTAURANT:	508
# 		APS SCHOOL FOOD SERVICE:	470
# 	Max length: 25
#  10. STREET_NUMBER
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 1349
# 	5 most frequent values:
# 		6600:	216
# 		10000:	152
# 		300:	143
# 		2200:	127
# 		8100:	125
# 	Max length: 7
#  11. STREET_NAME
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 404
# 	5 most frequent values:
# 		CENTRAL:	1898
# 		MENAUL:	928
# 		COORS:	918
# 		MONTGOMERY:	727
# 		SAN MATEO:	707
# 	Max length: 24
#  12. STREET_TYPE
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 13
# 	5 most frequent values:
# 		BLVD:	7636
# 		AV:	3005
# 		ST:	2065
# 		RD:	1900
# 		DR:	995
# 	Max length: 4
#  13. POST_DIRECTIONAL
# 	<class 'str'>
# 	Nulls: True
# 	Values: N, SW, NW, SE, NE
#  14. PHONE
# 	<class 'int'>
# 	Nulls: True
# 	Min: 2471094
# 	Max: 505345566137310
# 	Sum: 2608539289633190
# 	Mean: 161719732773.29138
# 	Median: 5053454060.0
# 	Standard Deviation: 8895791545525.992
# 	Unique values: 2279
# 	5 most frequent values:
# 		9153321301:	101
# 		3037929467:	100
# 		5052224033:	94
# 		3109680646:	85
# 		5052426777:	68
#  15. PROGRAM_CATEGORY
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 25
# 	5 most frequent values:
# 		0406:	7969
# 		0601:	1159
# 		0607:	894
# 		0606:	865
# 		0408:	832
# 	Max length: 4
#  16. PROGRAM_CATEGORY_DESCRIPTION
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 24
# 	5 most frequent values:
# 		Food Service Establishment:	7969
# 		Retail -Grocery:	1159
# 		Retail - Self Service & Prepackage Foods:	894
# 		Retail - Prepackage Only:	865
# 		Bar:	832
# 	Max length: 40
#  17. INSPECTION_DATE
# 	<class 'datetime.date'>
# 	Nulls: False
# 	Min: 2009-07-01
# 	Max: 2010-06-30
# 	Unique values: 258
# 	5 most frequent values:
# 		2009-12-16:	184
# 		2009-09-10:	159
# 		2009-09-25:	148
# 		2009-11-04:	133
# 		2009-10-01:	131
#  18. INSPECTION_TYPE
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#  19. INSPECTION_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 15
# 	5 most frequent values:
# 		ROUTINE FOOD INSPECTION:	12439
# 		EMERGENCY RESPONSE:	1987
# 		New Business Inspection:	1005
# 		PRE-OPENING FOOD INSPECTION:	743
# 		ADDITIONAL SERVICE PROVIDED:	439
# 	Max length: 32
#  20. SERIAL_NUM
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 9046
# 	5 most frequent values:
# 		DA0045731:	61
# 		DA0047290:	61
# 		DA0047720:	61
# 		DA0059230:	61
# 		DA0045676:	61
# 	Max length: 9
#  21. ACTION_CODE
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 8
# 	5 most frequent values:
# 		11:	14080
# 		00:	2800
# 		09:	382
# 		06:	264
# 		10:	21
# 	Max length: 2
#  22. ACTION_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 8
# 	5 most frequent values:
# 		APPROVED:	14080
# 		NON-GRADED:	2800
# 		ANNUAL STICKER ISSUED:	382
# 		UNSATISFACTORY:	264
# 		ANNUAL STICKER NOT ISSUED:	21
# 	Max length: 34
#  23. RESULT_CODE
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 19
# 	5 most frequent values:
# 		03:	14389
# 		00:	2416
# 		05:	214
# 		22:	142
# 		18:	104
# 	Max length: 2
#  24. RESULT_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 19
# 	5 most frequent values:
# 		IN COMPLIANCE:	14389
# 		NOT APPLICABLE:	2416
# 		DOWNGRADE:	214
# 		OUT OF BUSINESS:	142
# 		TRAINING RECEIVED:	104
# 	Max length: 37
#  25. VIOLATION_CODE
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 128
# 	5 most frequent values:
# 		55:	6348
# 		00:	3429
# 		68:	1658
# 		42:	487
# 		35:	441
# 	Max length: 10
#  26. VIOLATION_DESC
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 70
# 	5 most frequent values:
# 		Additional Comments:	6353
# 		No Violations Found:	3434
# 		Delivered Informational Brochure:	1657
# 		Plumbing: Improperly installed/maintained/supplied:	492
# 		Non-Food contact surfaces:	446
# 	Max length: 50
#  27. INSPECTION_MEMO
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#
# Row count: 17556

# %% [markdown]
# < Meaning of the columns & Whether they have null values >
#
# 1. FACILITY_NAME : Name of the facility where the inspection occured
# 2. FACILITY_KEY : The unique ID of the facility
# 3. SITE_ADDRESS : Street address of the facility (Null values included)
#
# 4. CITY . City of the facility
#
# 5. STATE . State of the facility
#
# 6. ZIP . Zip of the facility
#
# 7. OWNER_KEY . The unique ID of the Owner of the facility at the time of the inspection
#
# 8. OWNER_NAME . The name of the Owner of the facility at the time of the inspection
#
# 9. NATURE_OF_BUSINESS . The type of business (Null values included)
#
# 10. STREET_NUMBER . Street number of the facility (Null values included)
#
# 11. STREET_NAME . Street name of the facility (Null values included)
#
# 12. STREET_TYPE . Street type of the facility (Null values included)
#
# 13. POST_DIRECTIONAL . Postal direction of the facility (Null values included)
#
# 14. PHONE . Phone number of the facility (Null values included)
#
# 15. PROGRAM_CATEGORY . Id that indicates the type of facility permit the inspection was performed
#
# 16. PROGRAM_CATEGORY_DESCRIPTION . Descript of the Program category id (Null values included)
#
# 17. INSPECTION_DATE . Date the inspection occurred
#
# 18. INSPECTION_TYPE . Code for type of inspection (Null values included)
#
# 19. INSPECTION_DESC . Description of the inspection
#
# 20. SERIAL_NUM . Unique ID for the inspection daily activity
#
# 21. ACTION_CODE . Code of the action taken.
#
# 22. ACTION_DESC . Description of the action taken
#
# 23. RESULT_CODE . Code of the result of the inspection
#
# 24. RESULT_DESC . Description of the result of the inspection
#
# 25. VIOLATION_CODE . The code for the violation (Null values included)
#
# 26. VIOLATION_DESC . Description of the violation that was found (Null values included)
#
# 27. INSPECTION_MEMO . Notes from the inspection made by the inspector (Null values included)
#
#
# ==> I would like to know how many violations occured by region, time and Business type. To analyze the data to know that, I need the columns such as 'ZIP', 'NATURE_OF_BUSINESS', 'INSPECTION_DATE', 'VIOLATION_CODE', and 'VIOLATION_DESC'.

# %% [markdown]
# Insert a combination of code and text/markdown cells here to review the data and describe what you find.

# %% [markdown]
# ## Problem 2 - define a database model and load the data (35 points)
#
# Based on what you found above, create and connect to a new database, define a database table in it, and load this dataset into it.  You may use either of the methods for this step you have seen in earlier class notebooks.  You may choose to eliminate variables/columns if they are not relevant or interesting to you - explain your reasoning if you do.  Either way, you should load a majority of the columns present in the source dataset into the database and all of its rows.
#
# Once your data has loaded successfully, run a `COUNT(*)` query to verify that all the data has loaded correctly.
#
# Insert a combination of code and text/markdown cells here to connect to your database, define your table, load its data, and verify the loaded records.

# %%
# %load_ext sql
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /opt/conda/lib/python3.5/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
# !echo 'redspot' | sudo -S service postgresql restart
# Out:
# [sudo] password for jovyan: Restarting PostgreSQL 9.5 database server: main.

# %%
# !createdb -U dbuser Ex4
# Out:
# createdb: database creation failed: ERROR:  database "Ex4" already exists

# %%
# !echo "facility_name,facility_key,site_address,city,state,zip,owner_key,owner_name,nature_of_business,street_number,street_name,street_type,post_directional,phone,program_category,program_category_des,inspection_date,inspection_type,inspection_desc,serial_num,action_code,action_desc,result_code,result_desc,violation_code,violation_desc,inspection_memo" > food_inspection.csv

# %%
# %sql postgresql://dbuser@localhost:5432/Ex4
# Out:
# 'Connected: dbuser@Ex4'

# %%
# %%sql
# DROP TABLE IF EXISTS food_inspection;
# Out:
# Done.
# []

# %%
# !tail -n +2 abq-food-inspections-fy2010.csv >> food_inspection.csv

# %%
# !csvsql --db postgresql://dbuser@localhost:5432/Ex4 --insert food_inspection.csv

# %%
# %%sql
# SELECT * FROM food_inspection
# LIMIT 5;
# Out:
# 5 rows affected.
# [('00BSAY IT WITH CAKE', 50534, '10200 GOLF COURSE RD NW STE B', 'ALBUQUERQUE', 'NM', '87114', 47341, 'OOBSAY IT WITH CAKE', 'CAKE DECORATING', '10200', 'GOLF COURSE', 'RD', 'NW', 5058339563, '0405', 'Food Processor', datetime.date(2009, 10, 21), None, 'EMERGENCY RESPONSE', 'DA8009125', '00', 'NON-GRADED', '00', 'NOT APPLICABLE', '68', 'Delivered Informational Brochure', None),
#  ('00BSAY IT WITH CAKE', 50534, '10200 GOLF COURSE RD NW STE B', 'ALBUQUERQUE', 'NM', '87114', 47341, 'OOBSAY IT WITH CAKE', 'CAKE DECORATING', '10200', 'GOLF COURSE', 'RD', 'NW', 5058339563, '0405', 'Food Processor', datetime.date(2009, 10, 21), None, 'ROUTINE FOOD INSPECTION', 'DA8009123', '11', 'APPROVED', '03', 'IN COMPLIANCE', '00', 'No Violations Found', None),
#  ('00BSAY IT WITH CAKE', 50534, '10200 GOLF COURSE RD NW STE B', 'ALBUQUERQUE', 'NM', '87114', 47341, 'OOBSAY IT WITH CAKE', 'CAKE DECORATING', '10200', 'GOLF COURSE', 'RD', 'NW', 5058339563, '0405', 'Food Processor', datetime.date(2009, 10, 21), None, 'ROUTINE FOOD INSPECTION', 'DA8009123', '11', 'APPROVED', '03', 'IN COMPLIANCE', '55', 'Additional Comments', None),
#  ('00BSAY IT WITH CAKE', 50534, '10200 GOLF COURSE RD NW STE B', 'ALBUQUERQUE', 'NM', '87114', 47341, 'OOBSAY IT WITH CAKE', 'CAKE DECORATING', '10200', 'GOLF COURSE', 'RD', 'NW', 5058339563, '0405', 'Food Processor', datetime.date(2010, 4, 14), None, 'ROUTINE FOOD INSPECTION', 'DA8010205', '11', 'APPROVED', '03', 'IN COMPLIANCE', '00', 'No Violations Found', None),
#  ('00BSAY IT WITH CAKE', 50534, '10200 GOLF COURSE RD NW STE B', 'ALBUQUERQUE', 'NM', '87114', 47341, 'OOBSAY IT WITH CAKE', 'CAKE DECORATING', '10200', 'GOLF COURSE', 'RD', 'NW', 5058339563, '0405', 'Food Processor', datetime.date(2010, 4, 14), None, 'ROUTINE FOOD INSPECTION', 'DA8010205', '11', 'APPROVED', '03', 'IN COMPLIANCE', '55', 'Additional Comments', None)]

# %%
# %%sql
# SELECT count(*) FROM food_inspection;
# Out:
# 1 rows affected.
# [(17556,)]

# %%
# %%sql
# ALTER TABLE food_inspection
# DROP site_address, DROP COLUMN city, DROP COLUMN state, DROP COLUMN owner_key, DROP COLUMN owner_name, DROP COLUMN street_number, DROP COLUMN street_name, DROP COLUMN street_type, DROP COLUMN post_directional, DROP COLUMN phone, DROP COLUMN action_code, DROP COLUMN action_desc, DROP COLUMN inspection_memo;
# Out:
# Done.
# []

# %% [markdown]
# ## Problem 3 - explore your data (30 points)
#
# Now that the data is loaded, ask some questions of it!  Identify key variables of interest and note their ranges along with other useful descriptive statistics.  Choose and define a few lines of inquiry, execute queries for each, and describe what you find in your result sets.  Use any query techniques we've seen in class, including aggregate functions, transformations, subqueries, or others as appropriate.
#
# If you find interesting patterns, adding plots to your exploration would be useful.
#
# Insert a combination of code and text/markdown cells here to explore your data.

# %% [markdown]
# * To figure out what time of year has the most and the least violations, and what kind of violations occurred for each month, I split the inspection date field into 'YEAR'and 'Month'.

# %%
# %%sql
# ALTER TABLE food_inspection
# ADD COLUMN month INT, ADD COLUMN year INT;
# Out:
# Done.
# []

# %%
# %%sql
# UPDATE food_inspection
# SET month = EXTRACT(MONTH FROM inspection_date), year = EXTRACT(YEAR FROM inspection_date)
# Out:
# 17556 rows affected.
# []

# %% [markdown]
# * And I saw what kind of violations there are and how the violation codes look like. It looks like 'Additional Comments' and 'No Violations Found' are not actually a violation, so I decided to remove them from my search.

# %%
# %%sql
# SELECT DISTINCT violation_code, violation_desc
# FROM food_inspection
# ORDER BY violation_desc, violation_code;
# Out:
# 132 rows affected.
# [('07  H4', 'Additional Comments'),
#  ('55', 'Additional Comments'),
#  ('66', 'Additional Comments'),
#  ('\\', 'Additional Comments'),
#  (']', 'Additional Comments'),
#  (None, 'Additional Comments'),
#  ('04  13', 'Adulterated food'),
#  ('13', 'Adulterated food'),
#  ('04  08', 'Barehand Contact with ready to eat food'),
#  ('08', 'Barehand Contact with ready to eat food'),
#  ('04  15', 'Bent, swollen containers'),
#  ('15', 'Bent, swollen containers'),
#  ('01', 'Cold Holding'),
#  ('04  01', 'Cold Holding'),
#  ('04  61', 'Complaint Not Substantiated'),
#  ('61', 'Complaint Not Substantiated'),
#  ('04  60', 'Complaint Substantiated'),
#  ('60', 'Complaint Substantiated'),
#  ('04  11', 'Contaminated equipment'),
#  ('11', 'Contaminated equipment'),
#  ('04', 'Cooking Temperatures'),
#  ('04  04', 'Cooking Temperatures'),
#  ('04  05', 'Cooling, Heating Procedures'),
#  ('05', 'Cooling, Heating Procedures'),
#  ('04  18', 'Cross connection, back siphonage, backflow'),
#  ('68', 'Delivered Informational Brochure'),
#  ('57', 'Downgrade Statement'),
#  ('04  12', 'Enough facilities to maintain product temps'),
#  ('12', 'Enough facilities to maintain product temps'),
#  ('04  26', 'Evidence of insects'),
#  ('26', 'Evidence of insects'),
#  ('04  27', 'Evidence of rodents'),
#  ('27', 'Evidence of rodents'),
#  ('04  45', 'Floors, Walls, Ceilings'),
#  ('45', 'Floors, Walls, Ceilings'),
#  ('04  10', 'Food Cross Contamination'),
#  ('10', 'Food Cross Contamination'),
#  ('04  34', 'Food contact surfaces'),
#  ('34', 'Food contact surfaces'),
#  ('04  39', 'Food dispensing utensils improperly stored'),
#  ('39', 'Food dispensing utensils improperly stored'),
#  ('04  40', 'Food improperly labeled'),
#  ('40', 'Food improperly labeled'),
#  ('04  38', 'Food unprotected'),
#  ('38', 'Food unprotected'),
#  ('04  44', 'Garbage area improperly maintained or constructed'),
#  ('44', 'Garbage area improperly maintained or constructed'),
#  ('04  19', 'Handwash Facilities - Inaccessible, unavailable'),
#  ('19', 'Handwash Facilities - Inaccessible, unavailable'),
#  ('04  20', 'Handwash Facilities - Inadequate'),
#  ('20', 'Handwash Facilities - Inadequate'),
#  ('02', 'Hot Holding'),
#  ('04  02', 'Hot Holding'),
#  ('52', 'IMMEDIATE CLOSURE - IMMINENT HEALTH HAZARD'),
#  ('04  72', 'INFESTATION'),
#  ('04  07', 'Improper handwashing'),
#  ('07', 'Improper handwashing'),
#  ('04  21', 'Improper sanitizing'),
#  ('21', 'Improper sanitizing'),
#  ('04  32', 'Improper storage/handling of clean equipment/utens'),
#  ('32', 'Improper storage/handling of clean equipment/utens'),
#  ('04  22', 'Improper use of wiping cloths'),
#  ('22', 'Improper use of wiping cloths'),
#  ('04  16', 'Inadequate water source, Hot or cold'),
#  ('16', 'Inadequate water source, Hot or cold'),
#  ('04  28', 'Insect, rodents, animals - Other'),
#  ('28', 'Insect, rodents, animals - Other'),
#  ('04  70', 'LACK OF REFIGERATIONS'),
#  ('04  70', 'LACK OF REFRIGERATION'),
#  ('07  D1', 'Maintenance & Operation'),
#  ('04  69', 'NO HOT WATER'),
#  ('00', 'No Violations Found'),
#  ('04  00', 'No Violations Found'),
#  ('07  H1', 'No violations found at time of inspection.'),
#  ('04  35', 'Non-Food contact surfaces'),
#  ('35', 'Non-Food contact surfaces'),
#  ('56', 'Notice Statement'),
#  ('04  59', 'OBSERVATIONS'),
#  ('59', 'OBSERVATIONS'),
#  ('04  58', 'OPERATING WITHOUT A VALID PERMIT'),
#  ('58', 'OPERATING WITHOUT A VALID PERMIT'),
#  ('04  73', 'OTHER'),
#  ('02 15A0204', 'OTHER - MISCELLEANOUS'),
#  ('04  46', 'Other Operations - Lighting'),
#  ('46', 'Other Operations - Lighting'),
#  ('04  49', 'Other Operations - Linen'),
#  ('49', 'Other Operations - Linen'),
#  ('04  50', 'Other Operations - Living/Sleeping/Laundry'),
#  ('50', 'Other Operations - Living/Sleeping/Laundry'),
#  ('04  48', 'Other Operations - Personal Items'),
#  ('48', 'Other Operations - Personal Items'),
#  ('04  51', 'Other Operations - Premises'),
#  ('51', 'Other Operations - Premises'),
#  ('04  47', 'Other Operations - Ventilation'),
#  ('47', 'Other Operations - Ventilation'),
#  ('04  06', 'Personnel w/infection restricted/excluded'),
#  ('06', 'Personnel w/infection restricted/excluded'),
#  ('04  42', 'Plumbing: Improperly installed/maintained/supplied'),
#  ('42', 'Plumbing: Improperly installed/maintained/supplied'),
#  ('04  30', 'Poor Hygienic Practices- No hair restraints'),
#  ('30', 'Poor Hygienic Practices- No hair restraints'),
#  ('04  29', 'Poor Hygienic Practices- Soiled Clothing'),
#  ('29', 'Poor Hygienic Practices- Soiled Clothing'),
#  ('04  37', 'Potentially hazardous food improperly thawed'),
#  ('37', 'Potentially hazardous food improperly thawed'),
#  ('03', 'Reheating Temp'),
#  ('04  03', 'Reheating Temp'),
#  ('04  71', 'SEWAGE IN FACILITY'),
#  ('04  09', 'Smoking, Eating, Drinking'),
#  ('09', 'Smoking, Eating, Drinking'),
#  ('04  36', 'Thermometers not provided, not accurate/consp'),
#  ('36', 'Thermometers not provided, not accurate/consp'),
#  ('04  43', 'Toilet room fixtures'),
#  ('43', 'Toilet room fixtures'),
#  ('04  24', 'Toxic Items- Improper Labels'),
#  ('24', 'Toxic Items- Improper Labels'),
#  ('04  25', 'Toxic Items- Improper Storage'),
#  ('25', 'Toxic Items- Improper Storage'),
#  ('04  23', 'Toxic Items- Improper Usage'),
#  ('23', 'Toxic Items- Improper Usage'),
#  ('04  14', 'Unapproved Source'),
#  ('14', 'Unapproved Source'),
#  ('04  41', 'Unapproved container'),
#  ('41', 'Unapproved container'),
#  ('04  17', 'Unapproved sewage and wastewater disposal'),
#  ('17', 'Unapproved sewage and wastewater disposal'),
#  ('04  31', 'Warewashing Thermometers/Test Kits not provided'),
#  ('31', 'Warewashing Thermometers/Test Kits not provided'),
#  ('04  33', 'Warewashing facilities'),
#  ('33', 'Warewashing facilities'),
#  ('68', None),
#  (None, None)]

# %% [markdown]
# * I removed all values including null violation description and null violation code from my search, and got the percentage of violations occurred per all number of inspections executed for each month. I saw in October~December the most inspection executed and also the much higher violation rate compared to other months.

# %%
# %%sql
# SELECT a.year, a.month, a.Num_Insp, b.Num_VL, b.Num_VL*1.0/a.Num_Insp*100 AS pct_VL
# FROM
# (SELECT year, month, count(*) AS Num_Insp FROM food_inspection
#   WHERE violation_code NOT IN ('00') AND violation_code IS NOT NULL AND violation_desc IS NOT NULL AND violation_desc NOT IN ('None')
#  GROUP BY year, month
#  ORDER BY year, month) AS a,
#     (SELECT year, month, count(*) AS Num_VL FROM food_inspection
#     WHERE violation_code NOT IN ('00') AND violation_code IS NOT NULL AND violation_desc IS NOT NULL AND violation_desc NOT IN ('None')
#      AND violation_desc NOT LIKE 'Additional Comments%'
#      AND violation_desc NOT LIKE '%No Violations%' AND violation_desc NOT LIKE '%No violations%'
#     GROUP BY year, month) AS b
# WHERE a.year = b.year AND a.month = b.month;
# Out:
# 12 rows affected.
# [(2009, 7, 1168, 438, Decimal('37.50000000000000000000')),
#  (2009, 8, 1009, 406, Decimal('40.23785926660059464800')),
#  (2009, 9, 1579, 784, Decimal('49.65167827739075364200')),
#  (2009, 10, 1338, 831, Decimal('62.10762331838565022400')),
#  (2009, 11, 1339, 835, Decimal('62.35997012696041822300')),
#  (2009, 12, 1629, 1002, Decimal('61.51012891344383057100')),
#  (2010, 1, 1067, 487, Decimal('45.64198687910028116200')),
#  (2010, 2, 982, 445, Decimal('45.31568228105906313600')),
#  (2010, 3, 1122, 535, Decimal('47.68270944741532976800')),
#  (2010, 4, 943, 460, Decimal('48.78048780487804878000')),
#  (2010, 5, 386, 175, Decimal('45.33678756476683937800')),
#  (2010, 6, 555, 361, Decimal('65.04504504504504504500'))]

# %% [markdown]
# * I run the code below to see the type of violations happened often in those months, and found that most of the violations are 'Delivered Information Brochure.'

# %%
# %%sql
# SELECT year, month, violation_code, violation_desc, count(*) AS count
# FROM food_inspection
# WHERE month IN (10, 11, 12) AND violation_code NOT IN ('00') AND violation_code IS NOT NULL AND violation_desc IS NOT NULL AND violation_desc NOT IN ('None')
#      AND violation_desc NOT LIKE 'Additional Comments%'
#      AND violation_desc NOT LIKE '%No Violations%' AND violation_desc NOT LIKE '%No violations%'
# GROUP BY year, month, violation_code, violation_desc
# ORDER BY year, month, count DESC;
# Out:
# 196 rows affected.
# [(2009, 10, '68', 'Delivered Informational Brochure', 390),
#  (2009, 10, '35', 'Non-Food contact surfaces', 48),
#  (2009, 10, '42', 'Plumbing: Improperly installed/maintained/supplied', 43),
#  (2009, 10, '38', 'Food unprotected', 40),
#  (2009, 10, '21', 'Improper sanitizing', 36),
#  (2009, 10, '34', 'Food contact surfaces', 30),
#  (2009, 10, '45', 'Floors, Walls, Ceilings', 30),
#  (2009, 10, '01', 'Cold Holding', 26),
#  (2009, 10, '02', 'Hot Holding', 23),
#  (2009, 10, '36', 'Thermometers not provided, not accurate/consp', 21),
#  (2009, 10, '31', 'Warewashing Thermometers/Test Kits not provided', 14),
#  (2009, 10, '46', 'Other Operations - Lighting', 12),
#  (2009, 10, '32', 'Improper storage/handling of clean equipment/utens', 10),
#  (2009, 10, '22', 'Improper use of wiping cloths', 10),
#  (2009, 10, '51', 'Other Operations - Premises', 9),
#  (2009, 10, '33', 'Warewashing facilities', 9),
#  (2009, 10, '40', 'Food improperly labeled', 8),
#  (2009, 10, '24', 'Toxic Items- Improper Labels', 6),
#  (2009, 10, '09', 'Smoking, Eating, Drinking', 6),
#  (2009, 10, '39', 'Food dispensing utensils improperly stored', 5),
#  (2009, 10, '43', 'Toilet room fixtures', 5),
#  (2009, 10, '19', 'Handwash Facilities - Inaccessible, unavailable', 4),
#  (2009, 10, '12', 'Enough facilities to maintain product temps', 4),
#  (2009, 10, '07', 'Improper handwashing', 3),
#  (2009, 10, '37', 'Potentially hazardous food improperly thawed', 3),
#  (2009, 10, '16', 'Inadequate water source, Hot or cold', 3),
#  (2009, 10, '44', 'Garbage area improperly maintained or constructed', 3),
#  (2009, 10, '26', 'Evidence of insects', 3),
#  (2009, 10, '48', 'Other Operations - Personal Items', 3),
#  (2009, 10, '57', 'Downgrade Statement', 2),
#  (2009, 10, '17', 'Unapproved sewage and wastewater disposal', 2),
#  (2009, 10, '47', 'Other Operations - Ventilation', 2),
#  (2009, 10, '08', 'Barehand Contact with ready to eat food', 2),
#  (2009, 10, '27', 'Evidence of rodents', 2),
#  (2009, 10, '03', 'Reheating Temp', 2),
#  (2009, 10, '05', 'Cooling, Heating Procedures', 2),
#  (2009, 10, '25', 'Toxic Items- Improper Storage', 2),
#  (2009, 10, '13', 'Adulterated food', 1),
#  (2009, 10, '49', 'Other Operations - Linen', 1),
#  (2009, 10, '28', 'Insect, rodents, animals - Other', 1),
#  (2009, 10, '11', 'Contaminated equipment', 1),
#  (2009, 10, '50', 'Other Operations - Living/Sleeping/Laundry', 1),
#  (2009, 10, '04', 'Cooking Temperatures', 1),
#  (2009, 10, '23', 'Toxic Items- Improper Usage', 1),
#  (2009, 10, '58', 'OPERATING WITHOUT A VALID PERMIT', 1),
#  (2009, 11, '68', 'Delivered Informational Brochure', 389),
#  (2009, 11, '45', 'Floors, Walls, Ceilings', 50),
#  (2009, 11, '42', 'Plumbing: Improperly installed/maintained/supplied', 49),
#  (2009, 11, '38', 'Food unprotected', 45),
#  (2009, 11, '21', 'Improper sanitizing', 35),
#  (2009, 11, '35', 'Non-Food contact surfaces', 31),
#  (2009, 11, '34', 'Food contact surfaces', 19),
#  (2009, 11, '01', 'Cold Holding', 19),
#  (2009, 11, '36', 'Thermometers not provided, not accurate/consp', 18),
#  (2009, 11, '09', 'Smoking, Eating, Drinking', 14),
#  (2009, 11, '22', 'Improper use of wiping cloths', 13),
#  (2009, 11, '31', 'Warewashing Thermometers/Test Kits not provided', 13),
#  (2009, 11, '02', 'Hot Holding', 13),
#  (2009, 11, '32', 'Improper storage/handling of clean equipment/utens', 10),
#  (2009, 11, '46', 'Other Operations - Lighting', 10),
#  (2009, 11, '40', 'Food improperly labeled', 9),
#  (2009, 11, '19', 'Handwash Facilities - Inaccessible, unavailable', 9),
#  (2009, 11, '39', 'Food dispensing utensils improperly stored', 8),
#  (2009, 11, '48', 'Other Operations - Personal Items', 7),
#  (2009, 11, '58', 'OPERATING WITHOUT A VALID PERMIT', 7),
#  (2009, 11, '05', 'Cooling, Heating Procedures', 6),
#  (2009, 11, '16', 'Inadequate water source, Hot or cold', 5),
#  (2009, 11, '25', 'Toxic Items- Improper Storage', 5),
#  (2009, 11, '33', 'Warewashing facilities', 5),
#  (2009, 11, '51', 'Other Operations - Premises', 5),
#  (2009, 11, '24', 'Toxic Items- Improper Labels', 4),
#  (2009, 11, '37', 'Potentially hazardous food improperly thawed', 4),
#  (2009, 11, '57', 'Downgrade Statement', 4),
#  (2009, 11, '14', 'Unapproved Source', 3),
#  (2009, 11, '11', 'Contaminated equipment', 3),
#  (2009, 11, '07', 'Improper handwashing', 3),
#  (2009, 11, '13', 'Adulterated food', 3),
#  (2009, 11, '08', 'Barehand Contact with ready to eat food', 3),
#  (2009, 11, '03', 'Reheating Temp', 3),
#  (2009, 11, '44', 'Garbage area improperly maintained or constructed', 2),
#  (2009, 11, '43', 'Toilet room fixtures', 2),
#  (2009, 11, '26', 'Evidence of insects', 1),
#  (2009, 11, '15', 'Bent, swollen containers', 1),
#  (2009, 11, '20', 'Handwash Facilities - Inadequate', 1),
#  (2009, 11, '29', 'Poor Hygienic Practices- Soiled Clothing', 1),
#  (2009, 11, '10', 'Food Cross Contamination', 1),
#  (2009, 11, '23', 'Toxic Items- Improper Usage', 1),
#  (2009, 11, '49', 'Other Operations - Linen', 1),
#  (2009, 12, '68', 'Delivered Informational Brochure', 446),
#  (2009, 12, '42', 'Plumbing: Improperly installed/maintained/supplied', 49),
#  (2009, 12, '45', 'Floors, Walls, Ceilings', 43),
#  (2009, 12, '35', 'Non-Food contact surfaces', 43),
#  (2009, 12, '21', 'Improper sanitizing', 41),
#  (2009, 12, '38', 'Food unprotected', 39),
#  (2009, 12, '34', 'Food contact surfaces', 31),
#  (2009, 12, '46', 'Other Operations - Lighting', 20),
#  (2009, 12, '02', 'Hot Holding', 20),
#  (2009, 12, '01', 'Cold Holding', 15),
#  (2009, 12, '19', 'Handwash Facilities - Inaccessible, unavailable', 13),
#  (2009, 12, '40', 'Food improperly labeled', 12),
#  (2009, 12, '43', 'Toilet room fixtures', 11),
#  (2009, 12, '03', 'Reheating Temp', 11),
#  (2009, 12, '37', 'Potentially hazardous food improperly thawed', 11),
#  (2009, 12, '22', 'Improper use of wiping cloths', 11),
#  (2009, 12, '31', 'Warewashing Thermometers/Test Kits not provided', 11),
#  (2009, 12, '09', 'Smoking, Eating, Drinking', 11),
#  (2009, 12, '32', 'Improper storage/handling of clean equipment/utens', 10),
#  (2009, 12, '58', 'OPERATING WITHOUT A VALID PERMIT', 10),
#  (2009, 12, '33', 'Warewashing facilities', 10),
#  (2009, 12, '36', 'Thermometers not provided, not accurate/consp', 8),
#  (2009, 12, '48', 'Other Operations - Personal Items', 7),
#  (2009, 12, '39', 'Food dispensing utensils improperly stored', 6),
#  (2009, 12, '07', 'Improper handwashing', 5),
#  (2009, 12, '51', 'Other Operations - Premises', 4),
#  (2009, 12, '41', 'Unapproved container', 4),
#  (2009, 12, '47', 'Other Operations - Ventilation', 4),
#  (2009, 12, '16', 'Inadequate water source, Hot or cold', 3),
#  (2009, 12, '17', 'Unapproved sewage and wastewater disposal', 3),
#  (2009, 12, '44', 'Garbage area improperly maintained or constructed', 3),
#  (2009, 12, '10', 'Food Cross Contamination', 3),
#  (2009, 12, '15', 'Bent, swollen containers', 3),
#  (2009, 12, '23', 'Toxic Items- Improper Usage', 2),
#  (2009, 12, '20', 'Handwash Facilities - Inadequate', 2),
#  (2009, 12, '57', 'Downgrade Statement', 2),
#  (2009, 12, '05', 'Cooling, Heating Procedures', 2),
#  (2009, 12, '27', 'Evidence of rodents', 2),
#  (2009, 12, '08', 'Barehand Contact with ready to eat food', 2),
#  (2009, 12, '30', 'Poor Hygienic Practices- No hair restraints', 1),
#  (2009, 12, '04  08', 'Barehand Contact with ready to eat food', 1),
#  (2009, 12, '04  16', 'Inadequate water source, Hot or cold', 1),
#  (2009, 12, '04  39', 'Food dispensing utensils improperly stored', 1),
#  (2009, 12, '04  41', 'Unapproved container', 1),
#  (2009, 12, '04  28', 'Insect, rodents, animals - Other', 1),
#  (2009, 12, '04  70', 'LACK OF REFRIGERATION', 1),
#  (2009, 12, '04  36', 'Thermometers not provided, not accurate/consp', 1),
#  (2009, 12, '04  51', 'Other Operations - Premises', 1),
#  (2009, 12, '04  46', 'Other Operations - Lighting', 1),
#  (2009, 12, '04  05', 'Cooling, Heating Procedures', 1),
#  (2009, 12, '04  24', 'Toxic Items- Improper Labels', 1),
#  (2009, 12, '04  43', 'Toilet room fixtures', 1),
#  (2009, 12, '04  29', 'Poor Hygienic Practices- Soiled Clothing', 1),
#  (2009, 12, '04  33', 'Warewashing facilities', 1),
#  (2009, 12, '04  42', 'Plumbing: Improperly installed/maintained/supplied', 1),
#  (2009, 12, '04  48', 'Other Operations - Personal Items', 1),
#  (2009, 12, '04  25', 'Toxic Items- Improper Storage', 1),
#  (2009, 12, '26', 'Evidence of insects', 1),
#  (2009, 12, '12', 'Enough facilities to maintain product temps', 1),
#  (2009, 12, '04  69', 'NO HOT WATER', 1),
#  (2009, 12, '04  13', 'Adulterated food', 1),
#  (2009, 12, '04  11', 'Contaminated equipment', 1),
#  (2009, 12, '04  14', 'Unapproved Source', 1),
#  (2009, 12, '04  58', 'OPERATING WITHOUT A VALID PERMIT', 1),
#  (2009, 12, '04  49', 'Other Operations - Linen', 1),
#  (2009, 12, '04  32', 'Improper storage/handling of clean equipment/utens', 1),
#  (2009, 12, '04  20', 'Handwash Facilities - Inadequate', 1),
#  (2009, 12, '04  31', 'Warewashing Thermometers/Test Kits not provided', 1),
#  (2009, 12, '04  50', 'Other Operations - Living/Sleeping/Laundry', 1),
#  (2009, 12, '04  37', 'Potentially hazardous food improperly thawed', 1),
#  (2009, 12, '04  26', 'Evidence of insects', 1),
#  (2009, 12, '04  04', 'Cooking Temperatures', 1),
#  (2009, 12, '04  17', 'Unapproved sewage and wastewater disposal', 1),
#  (2009, 12, '04  19', 'Handwash Facilities - Inaccessible, unavailable', 1),
#  (2009, 12, '04  07', 'Improper handwashing', 1),
#  (2009, 12, '04  02', 'Hot Holding', 1),
#  (2009, 12, '04  35', 'Non-Food contact surfaces', 1),
#  (2009, 12, '04  71', 'SEWAGE IN FACILITY', 1),
#  (2009, 12, '04  23', 'Toxic Items- Improper Usage', 1),
#  (2009, 12, '04  03', 'Reheating Temp', 1),
#  (2009, 12, '04  38', 'Food unprotected', 1),
#  (2009, 12, '04  27', 'Evidence of rodents', 1),
#  (2009, 12, '04  22', 'Improper use of wiping cloths', 1),
#  (2009, 12, '04  30', 'Poor Hygienic Practices- No hair restraints', 1),
#  (2009, 12, '13', 'Adulterated food', 1),
#  (2009, 12, '04  73', 'OTHER', 1),
#  (2009, 12, '04  10', 'Food Cross Contamination', 1),
#  (2009, 12, '04  45', 'Floors, Walls, Ceilings', 1),
#  (2009, 12, '04  72', 'INFESTATION', 1),
#  (2009, 12, '02 15A0204', 'OTHER - MISCELLEANOUS', 1),
#  (2009, 12, '24', 'Toxic Items- Improper Labels', 1),
#  (2009, 12, '04  61', 'Complaint Not Substantiated', 1),
#  (2009, 12, '04  34', 'Food contact surfaces', 1),
#  (2009, 12, '14', 'Unapproved Source', 1),
#  (2009, 12, '04  60', 'Complaint Substantiated', 1),
#  (2009, 12, '04  44', 'Garbage area improperly maintained or constructed', 1),
#  (2009, 12, '04  47', 'Other Operations - Ventilation', 1),
#  (2009, 12, '04  01', 'Cold Holding', 1),
#  (2009, 12, '04  12', 'Enough facilities to maintain product temps', 1),
#  (2009, 12, '04  40', 'Food improperly labeled', 1),
#  (2009, 12, '04  09', 'Smoking, Eating, Drinking', 1),
#  (2009, 12, '04  21', 'Improper sanitizing', 1),
#  (2009, 12, '25', 'Toxic Items- Improper Storage', 1),
#  (2009, 12, '04  15', 'Bent, swollen containers', 1),
#  (2009, 12, '04  59', 'OBSERVATIONS', 1),
#  (2009, 12, '04  06', 'Personnel w/infection restricted/excluded', 1),
#  (2009, 12, '04  18', 'Cross connection, back siphonage, backflow', 1),
#  (2009, 12, '50', 'Other Operations - Living/Sleeping/Laundry', 1)]

# %% [markdown]
# * Since the brochure delivery violation is not directly related sanitary conditions of the resturants that I am interested of, I decided to remove it from my search and rerun the code above. Now I can see that the violation rate for those months(10~12) decreased a lot, but there is not much difference for the rest of the months. I guess its reason might be that there are especially the biggest holidays between Octover and December. Restaurants might want to send a lot of brochures and invitations to customers to attract them for the big events.
# * Without the brocure violations, June has the highest violation rate compared to its low number of inspection.

# %%
# %%sql
# SELECT a.year, a.month, a.Num_Insp, b.Num_VL, b.Num_VL*1.0/a.Num_Insp*100 AS pct_VL
# FROM
# (SELECT year, month, count(*) AS Num_Insp FROM food_inspection
#   WHERE violation_code NOT IN ('00') AND violation_code IS NOT NULL AND violation_desc IS NOT NULL AND violation_desc NOT IN ('None')
#  GROUP BY year, month
#  ORDER BY year, month) AS a,
#     (SELECT year, month, count(*) AS Num_VL FROM food_inspection
#     WHERE violation_code NOT IN ('00','68','42') AND violation_code IS NOT NULL AND violation_desc IS NOT NULL AND violation_desc NOT IN ('None')
#      AND violation_desc NOT LIKE 'Additional Comments%'
#      AND violation_desc NOT LIKE '%No Violations%' AND violation_desc NOT LIKE '%No violations%'
#     GROUP BY year, month) AS b
# WHERE a.year = b.year AND a.month = b.month;
# Out:
# 12 rows affected.
# [(2009, 7, 1168, 392, Decimal('33.56164383561643835600')),
#  (2009, 8, 1009, 365, Decimal('36.17443012884043607500')),
#  (2009, 9, 1579, 398, Decimal('25.20582647245091830300')),
#  (2009, 10, 1338, 398, Decimal('29.74588938714499252600')),
#  (2009, 11, 1339, 397, Decimal('29.64899178491411501100')),
#  (2009, 12, 1629, 507, Decimal('31.12338858195211786400')),
#  (2010, 1, 1067, 359, Decimal('33.64573570759137769400')),
#  (2010, 2, 982, 399, Decimal('40.63136456211812627300')),
#  (2010, 3, 1122, 481, Decimal('42.86987522281639928700')),
#  (2010, 4, 943, 415, Decimal('44.00848356309650053000')),
#  (2010, 5, 386, 160, Decimal('41.45077720207253886000')),
#  (2010, 6, 555, 344, Decimal('61.98198198198198198200'))]

# %% [markdown]
# * it looks like there are relatively more violations related to hygiene in June than October~December. It might be a seasonal effect? The temperature in Albuquerque is the highest in June. I will find out about that later using more data.

# %%
# %%sql
# SELECT year, month, violation_desc, count(*) AS count
# FROM food_inspection
# WHERE month IN (6,7, 10,11,12) AND violation_code NOT IN ('00') AND violation_code IS NOT NULL AND violation_desc IS NOT NULL AND violation_desc NOT IN ('None')
#      AND violation_desc NOT LIKE 'Additional Comments%'
#      AND violation_desc NOT LIKE '%No Violations%' AND violation_desc NOT LIKE '%No violations%'
# GROUP BY year, month, violation_code, violation_desc
# ORDER BY year, month, count DESC;
# Out:
# 342 rows affected.
# [(2009, 7, 'Plumbing: Improperly installed/maintained/supplied', 46),
#  (2009, 7, 'Floors, Walls, Ceilings', 43),
#  (2009, 7, 'Food unprotected', 37),
#  (2009, 7, 'Non-Food contact surfaces', 36),
#  (2009, 7, 'Improper sanitizing', 29),
#  (2009, 7, 'Hot Holding', 23),
#  (2009, 7, 'Cold Holding', 23),
#  (2009, 7, 'Food contact surfaces', 22),
#  (2009, 7, 'Other Operations - Lighting', 18),
#  (2009, 7, 'Other Operations - Premises', 18),
#  (2009, 7, 'Evidence of insects', 13),
#  (2009, 7, 'Smoking, Eating, Drinking', 11),
#  (2009, 7, 'Thermometers not provided, not accurate/consp', 10),
#  (2009, 7, 'Toilet room fixtures', 9),
#  (2009, 7, 'Warewashing Thermometers/Test Kits not provided', 9),
#  (2009, 7, 'Food dispensing utensils improperly stored', 9),
#  (2009, 7, 'Barehand Contact with ready to eat food', 7),
#  (2009, 7, 'Improper use of wiping cloths', 6),
#  (2009, 7, 'Food improperly labeled', 6),
#  (2009, 7, 'Improper storage/handling of clean equipment/utens', 5),
#  (2009, 7, 'Potentially hazardous food improperly thawed', 5),
#  (2009, 7, 'Handwash Facilities - Inaccessible, unavailable', 5),
#  (2009, 7, 'Poor Hygienic Practices- No hair restraints', 4),
#  (2009, 7, 'Improper handwashing', 4),
#  (2009, 7, 'Warewashing facilities', 4),
#  (2009, 7, 'Cooling, Heating Procedures', 4),
#  (2009, 7, 'Garbage area improperly maintained or constructed', 3),
#  (2009, 7, 'Contaminated equipment', 3),
#  (2009, 7, 'Adulterated food', 2),
#  (2009, 7, 'Other Operations - Linen', 2),
#  (2009, 7, 'Reheating Temp', 2),
#  (2009, 7, 'IMMEDIATE CLOSURE - IMMINENT HEALTH HAZARD', 2),
#  (2009, 7, 'Complaint Substantiated', 2),
#  (2009, 7, 'Unapproved Source', 2),
#  (2009, 7, 'Enough facilities to maintain product temps', 2),
#  (2009, 7, 'Inadequate water source, Hot or cold', 2),
#  (2009, 7, 'Bent, swollen containers', 2),
#  (2009, 7, 'Toxic Items- Improper Usage', 1),
#  (2009, 7, 'Other Operations - Personal Items', 1),
#  (2009, 7, 'Toxic Items- Improper Labels', 1),
#  (2009, 7, 'Food Cross Contamination', 1),
#  (2009, 7, 'Insect, rodents, animals - Other', 1),
#  (2009, 7, 'OPERATING WITHOUT A VALID PERMIT', 1),
#  (2009, 7, 'Toxic Items- Improper Storage', 1),
#  (2009, 7, 'Downgrade Statement', 1),
#  (2009, 10, 'Delivered Informational Brochure', 390),
#  (2009, 10, 'Non-Food contact surfaces', 48),
#  (2009, 10, 'Plumbing: Improperly installed/maintained/supplied', 43),
#  (2009, 10, 'Food unprotected', 40),
#  (2009, 10, 'Improper sanitizing', 36),
#  (2009, 10, 'Floors, Walls, Ceilings', 30),
#  (2009, 10, 'Food contact surfaces', 30),
#  (2009, 10, 'Cold Holding', 26),
#  (2009, 10, 'Hot Holding', 23),
#  (2009, 10, 'Thermometers not provided, not accurate/consp', 21),
#  (2009, 10, 'Warewashing Thermometers/Test Kits not provided', 14),
#  (2009, 10, 'Other Operations - Lighting', 12),
#  (2009, 10, 'Improper storage/handling of clean equipment/utens', 10),
#  (2009, 10, 'Improper use of wiping cloths', 10),
#  (2009, 10, 'Warewashing facilities', 9),
#  (2009, 10, 'Other Operations - Premises', 9),
#  (2009, 10, 'Food improperly labeled', 8),
#  (2009, 10, 'Smoking, Eating, Drinking', 6),
#  (2009, 10, 'Toxic Items- Improper Labels', 6),
#  (2009, 10, 'Toilet room fixtures', 5),
#  (2009, 10, 'Food dispensing utensils improperly stored', 5),
#  (2009, 10, 'Enough facilities to maintain product temps', 4),
#  (2009, 10, 'Handwash Facilities - Inaccessible, unavailable', 4),
#  (2009, 10, 'Potentially hazardous food improperly thawed', 3),
#  (2009, 10, 'Evidence of insects', 3),
#  (2009, 10, 'Other Operations - Personal Items', 3),
#  (2009, 10, 'Garbage area improperly maintained or constructed', 3),
#  (2009, 10, 'Improper handwashing', 3),
#  (2009, 10, 'Inadequate water source, Hot or cold', 3),
#  (2009, 10, 'Reheating Temp', 2),
#  (2009, 10, 'Barehand Contact with ready to eat food', 2),
#  (2009, 10, 'Cooling, Heating Procedures', 2),
#  (2009, 10, 'Toxic Items- Improper Storage', 2),
#  (2009, 10, 'Other Operations - Ventilation', 2),
#  (2009, 10, 'Downgrade Statement', 2),
#  (2009, 10, 'Unapproved sewage and wastewater disposal', 2),
#  (2009, 10, 'Evidence of rodents', 2),
#  (2009, 10, 'Contaminated equipment', 1),
#  (2009, 10, 'Adulterated food', 1),
#  (2009, 10, 'OPERATING WITHOUT A VALID PERMIT', 1),
#  (2009, 10, 'Other Operations - Living/Sleeping/Laundry', 1),
#  (2009, 10, 'Insect, rodents, animals - Other', 1),
#  (2009, 10, 'Cooking Temperatures', 1),
#  (2009, 10, 'Toxic Items- Improper Usage', 1),
#  (2009, 10, 'Other Operations - Linen', 1),
#  (2009, 11, 'Delivered Informational Brochure', 389),
#  (2009, 11, 'Floors, Walls, Ceilings', 50),
#  (2009, 11, 'Plumbing: Improperly installed/maintained/supplied', 49),
#  (2009, 11, 'Food unprotected', 45),
#  (2009, 11, 'Improper sanitizing', 35),
#  (2009, 11, 'Non-Food contact surfaces', 31),
#  (2009, 11, 'Food contact surfaces', 19),
#  (2009, 11, 'Cold Holding', 19),
#  (2009, 11, 'Thermometers not provided, not accurate/consp', 18),
#  (2009, 11, 'Smoking, Eating, Drinking', 14),
#  (2009, 11, 'Improper use of wiping cloths', 13),
#  (2009, 11, 'Warewashing Thermometers/Test Kits not provided', 13),
#  (2009, 11, 'Hot Holding', 13),
#  (2009, 11, 'Other Operations - Lighting', 10),
#  (2009, 11, 'Improper storage/handling of clean equipment/utens', 10),
#  (2009, 11, 'Handwash Facilities - Inaccessible, unavailable', 9),
#  (2009, 11, 'Food improperly labeled', 9),
#  (2009, 11, 'Food dispensing utensils improperly stored', 8),
#  (2009, 11, 'OPERATING WITHOUT A VALID PERMIT', 7),
#  (2009, 11, 'Other Operations - Personal Items', 7),
#  (2009, 11, 'Cooling, Heating Procedures', 6),
#  (2009, 11, 'Inadequate water source, Hot or cold', 5),
#  (2009, 11, 'Other Operations - Premises', 5),
#  (2009, 11, 'Toxic Items- Improper Storage', 5),
#  (2009, 11, 'Warewashing facilities', 5),
#  (2009, 11, 'Potentially hazardous food improperly thawed', 4),
#  (2009, 11, 'Downgrade Statement', 4),
#  (2009, 11, 'Toxic Items- Improper Labels', 4),
#  (2009, 11, 'Improper handwashing', 3),
#  (2009, 11, 'Contaminated equipment', 3),
#  (2009, 11, 'Barehand Contact with ready to eat food', 3),
#  (2009, 11, 'Adulterated food', 3),
#  (2009, 11, 'Reheating Temp', 3),
#  (2009, 11, 'Unapproved Source', 3),
#  (2009, 11, 'Garbage area improperly maintained or constructed', 2),
#  (2009, 11, 'Toilet room fixtures', 2),
#  (2009, 11, 'Food Cross Contamination', 1),
#  (2009, 11, 'Other Operations - Linen', 1),
#  (2009, 11, 'Toxic Items- Improper Usage', 1),
#  (2009, 11, 'Evidence of insects', 1),
#  (2009, 11, 'Handwash Facilities - Inadequate', 1),
#  (2009, 11, 'Poor Hygienic Practices- Soiled Clothing', 1),
#  (2009, 11, 'Bent, swollen containers', 1),
#  (2009, 12, 'Delivered Informational Brochure', 446),
#  (2009, 12, 'Plumbing: Improperly installed/maintained/supplied', 49),
#  (2009, 12, 'Non-Food contact surfaces', 43),
#  (2009, 12, 'Floors, Walls, Ceilings', 43),
#  (2009, 12, 'Improper sanitizing', 41),
#  (2009, 12, 'Food unprotected', 39),
#  (2009, 12, 'Food contact surfaces', 31),
#  (2009, 12, 'Other Operations - Lighting', 20),
#  (2009, 12, 'Hot Holding', 20),
#  (2009, 12, 'Cold Holding', 15),
#  (2009, 12, 'Handwash Facilities - Inaccessible, unavailable', 13),
#  (2009, 12, 'Food improperly labeled', 12),
#  (2009, 12, 'Potentially hazardous food improperly thawed', 11),
#  (2009, 12, 'Smoking, Eating, Drinking', 11),
#  (2009, 12, 'Warewashing Thermometers/Test Kits not provided', 11),
#  (2009, 12, 'Improper use of wiping cloths', 11),
#  (2009, 12, 'Reheating Temp', 11),
#  (2009, 12, 'Toilet room fixtures', 11),
#  (2009, 12, 'OPERATING WITHOUT A VALID PERMIT', 10),
#  (2009, 12, 'Warewashing facilities', 10),
#  (2009, 12, 'Improper storage/handling of clean equipment/utens', 10),
#  (2009, 12, 'Thermometers not provided, not accurate/consp', 8),
#  (2009, 12, 'Other Operations - Personal Items', 7),
#  (2009, 12, 'Food dispensing utensils improperly stored', 6),
#  (2009, 12, 'Improper handwashing', 5),
#  (2009, 12, 'Unapproved container', 4),
#  (2009, 12, 'Other Operations - Ventilation', 4),
#  (2009, 12, 'Other Operations - Premises', 4),
#  (2009, 12, 'Unapproved sewage and wastewater disposal', 3),
#  (2009, 12, 'Bent, swollen containers', 3),
#  (2009, 12, 'Food Cross Contamination', 3),
#  (2009, 12, 'Inadequate water source, Hot or cold', 3),
#  (2009, 12, 'Garbage area improperly maintained or constructed', 3),
#  (2009, 12, 'Cooling, Heating Procedures', 2),
#  (2009, 12, 'Toxic Items- Improper Usage', 2),
#  (2009, 12, 'Barehand Contact with ready to eat food', 2),
#  (2009, 12, 'Evidence of rodents', 2),
#  (2009, 12, 'Downgrade Statement', 2),
#  (2009, 12, 'Handwash Facilities - Inadequate', 2),
#  (2009, 12, 'Improper handwashing', 1),
#  (2009, 12, 'Evidence of insects', 1),
#  (2009, 12, 'Warewashing Thermometers/Test Kits not provided', 1),
#  (2009, 12, 'OPERATING WITHOUT A VALID PERMIT', 1),
#  (2009, 12, 'NO HOT WATER', 1),
#  (2009, 12, 'Evidence of insects', 1),
#  (2009, 12, 'Plumbing: Improperly installed/maintained/supplied', 1),
#  (2009, 12, 'Other Operations - Lighting', 1),
#  (2009, 12, 'Other Operations - Premises', 1),
#  (2009, 12, 'Personnel w/infection restricted/excluded', 1),
#  (2009, 12, 'Bent, swollen containers', 1),
#  (2009, 12, 'Cold Holding', 1),
#  (2009, 12, 'Food contact surfaces', 1),
#  (2009, 12, 'SEWAGE IN FACILITY', 1),
#  (2009, 12, 'Toxic Items- Improper Usage', 1),
#  (2009, 12, 'Reheating Temp', 1),
#  (2009, 12, 'Improper use of wiping cloths', 1),
#  (2009, 12, 'Food Cross Contamination', 1),
#  (2009, 12, 'Complaint Substantiated', 1),
#  (2009, 12, 'Smoking, Eating, Drinking', 1),
#  (2009, 12, 'Improper sanitizing', 1),
#  (2009, 12, 'OBSERVATIONS', 1),
#  (2009, 12, 'Poor Hygienic Practices- No hair restraints', 1),
#  (2009, 12, 'Insect, rodents, animals - Other', 1),
#  (2009, 12, 'Cooling, Heating Procedures', 1),
#  (2009, 12, 'Toxic Items- Improper Labels', 1),
#  (2009, 12, 'Toilet room fixtures', 1),
#  (2009, 12, 'Poor Hygienic Practices- Soiled Clothing', 1),
#  (2009, 12, 'Warewashing facilities', 1),
#  (2009, 12, 'Other Operations - Personal Items', 1),
#  (2009, 12, 'Enough facilities to maintain product temps', 1),
#  (2009, 12, 'Adulterated food', 1),
#  (2009, 12, 'Unapproved Source', 1),
#  (2009, 12, 'Improper storage/handling of clean equipment/utens', 1),
#  (2009, 12, 'Handwash Facilities - Inadequate', 1),
#  (2009, 12, 'Other Operations - Living/Sleeping/Laundry', 1),
#  (2009, 12, 'Cooking Temperatures', 1),
#  (2009, 12, 'Unapproved sewage and wastewater disposal', 1),
#  (2009, 12, 'Food improperly labeled', 1),
#  (2009, 12, 'INFESTATION', 1),
#  (2009, 12, 'Floors, Walls, Ceilings', 1),
#  (2009, 12, 'Adulterated food', 1),
#  (2009, 12, 'Hot Holding', 1),
#  (2009, 12, 'Handwash Facilities - Inaccessible, unavailable', 1),
#  (2009, 12, 'Non-Food contact surfaces', 1),
#  (2009, 12, 'Food unprotected', 1),
#  (2009, 12, 'Poor Hygienic Practices- No hair restraints', 1),
#  (2009, 12, 'OTHER - MISCELLEANOUS', 1),
#  (2009, 12, 'Toxic Items- Improper Labels', 1),
#  (2009, 12, 'Complaint Not Substantiated', 1),
#  (2009, 12, 'Unapproved Source', 1),
#  (2009, 12, 'Other Operations - Ventilation', 1),
#  (2009, 12, 'Enough facilities to maintain product temps', 1),
#  (2009, 12, 'Toxic Items- Improper Storage', 1),
#  (2009, 12, 'Cross connection, back siphonage, backflow', 1),
#  (2009, 12, 'Barehand Contact with ready to eat food', 1),
#  (2009, 12, 'Inadequate water source, Hot or cold', 1),
#  (2009, 12, 'Food dispensing utensils improperly stored', 1),
#  (2009, 12, 'Potentially hazardous food improperly thawed', 1),
#  (2009, 12, 'Other Operations - Linen', 1),
#  (2009, 12, 'Contaminated equipment', 1),
#  (2009, 12, 'Toxic Items- Improper Storage', 1),
#  (2009, 12, 'Thermometers not provided, not accurate/consp', 1),
#  (2009, 12, 'LACK OF REFRIGERATION', 1),
#  (2009, 12, 'Unapproved container', 1),
#  (2009, 12, 'Other Operations - Living/Sleeping/Laundry', 1),
#  (2009, 12, 'Garbage area improperly maintained or constructed', 1),
#  (2009, 12, 'OTHER', 1),
#  (2009, 12, 'Evidence of rodents', 1),
#  (2010, 6, 'Food unprotected', 21),
#  (2010, 6, 'Improper sanitizing', 19),
#  (2010, 6, 'Plumbing: Improperly installed/maintained/supplied', 17),
#  (2010, 6, 'Floors, Walls, Ceilings', 14),
#  (2010, 6, 'Non-Food contact surfaces', 13),
#  (2010, 6, 'Food contact surfaces', 10),
#  (2010, 6, 'Improper use of wiping cloths', 8),
#  (2010, 6, 'Thermometers not provided, not accurate/consp', 8),
#  (2010, 6, 'Cold Holding', 7),
#  (2010, 6, 'Other Operations - Lighting', 7),
#  (2010, 6, 'Food improperly labeled', 6),
#  (2010, 6, 'Improper storage/handling of clean equipment/utens', 5),
#  (2010, 6, 'Hot Holding', 4),
#  (2010, 6, 'Warewashing Thermometers/Test Kits not provided', 4),
#  (2010, 6, 'Adulterated food', 4),
#  (2010, 6, 'Plumbing: Improperly installed/maintained/supplied', 3),
#  (2010, 6, 'Toilet room fixtures', 3),
#  (2010, 6, 'Toxic Items- Improper Storage', 3),
#  (2010, 6, 'Cold Holding', 3),
#  (2010, 6, 'Inadequate water source, Hot or cold', 3),
#  (2010, 6, 'Food dispensing utensils improperly stored', 3),
#  (2010, 6, 'Cooling, Heating Procedures', 3),
#  (2010, 6, 'Thermometers not provided, not accurate/consp', 3),
#  (2010, 6, 'Other Operations - Living/Sleeping/Laundry', 3),
#  (2010, 6, 'Other Operations - Premises', 3),
#  (2010, 6, 'Unapproved container', 3),
#  (2010, 6, 'Cross connection, back siphonage, backflow', 3),
#  (2010, 6, 'OTHER', 3),
#  (2010, 6, 'Evidence of rodents', 3),
#  (2010, 6, 'SEWAGE IN FACILITY', 3),
#  (2010, 6, 'Other Operations - Linen', 3),
#  (2010, 6, 'Poor Hygienic Practices- Soiled Clothing', 3),
#  (2010, 6, 'Warewashing Thermometers/Test Kits not provided', 3),
#  (2010, 6, 'Potentially hazardous food improperly thawed', 3),
#  (2010, 6, 'Food contact surfaces', 3),
#  (2010, 6, 'Garbage area improperly maintained or constructed', 3),
#  (2010, 6, 'NO HOT WATER', 3),
#  (2010, 6, 'Toxic Items- Improper Labels', 3),
#  (2010, 6, 'Contaminated equipment', 3),
#  (2010, 6, 'OPERATING WITHOUT A VALID PERMIT', 3),
#  (2010, 6, 'Other Operations - Lighting', 3),
#  (2010, 6, 'Floors, Walls, Ceilings', 3),
#  (2010, 6, 'INFESTATION', 3),
#  (2010, 6, 'Food unprotected', 3),
#  (2010, 6, 'Non-Food contact surfaces', 3),
#  (2010, 6, 'Enough facilities to maintain product temps', 3),
#  (2010, 6, 'Handwash Facilities - Inaccessible, unavailable', 3),
#  (2010, 6, 'Warewashing facilities', 3),
#  (2010, 6, 'Handwash Facilities - Inadequate', 3),
#  (2010, 6, 'Improper storage/handling of clean equipment/utens', 3),
#  (2010, 6, 'Other Operations - Personal Items', 3),
#  (2010, 6, 'Hot Holding', 3),
#  (2010, 6, 'Complaint Substantiated', 3),
#  (2010, 6, 'Complaint Not Substantiated', 3),
#  (2010, 6, 'Improper use of wiping cloths', 3),
#  (2010, 6, 'Improper sanitizing', 3),
#  (2010, 6, 'Smoking, Eating, Drinking', 3),
#  (2010, 6, 'Poor Hygienic Practices- No hair restraints', 3),
#  (2010, 6, 'Insect, rodents, animals - Other', 3),
#  (2010, 6, 'OBSERVATIONS', 3),
#  (2010, 6, 'Food Cross Contamination', 3),
#  (2010, 6, 'Improper handwashing', 3),
#  (2010, 6, 'Barehand Contact with ready to eat food', 3),
#  (2010, 6, 'Evidence of insects', 3),
#  (2010, 6, 'Reheating Temp', 3),
#  (2010, 6, 'Toxic Items- Improper Usage', 3),
#  (2010, 6, 'OPERATING WITHOUT A VALID PERMIT', 3),
#  (2010, 6, 'Bent, swollen containers', 3),
#  (2010, 6, 'Personnel w/infection restricted/excluded', 3),
#  (2010, 6, 'Adulterated food', 3),
#  (2010, 6, 'Food improperly labeled', 3),
#  (2010, 6, 'Unapproved sewage and wastewater disposal', 3),
#  (2010, 6, 'Cooking Temperatures', 3),
#  (2010, 6, 'Other Operations - Ventilation', 3),
#  (2010, 6, 'Unapproved Source', 3),
#  (2010, 6, 'Complaint Not Substantiated', 2),
#  (2010, 6, 'LACK OF REFIGERATIONS', 2),
#  (2010, 6, 'Food dispensing utensils improperly stored', 2),
#  (2010, 6, 'Inadequate water source, Hot or cold', 2),
#  (2010, 6, 'Improper handwashing', 2),
#  (2010, 6, 'Potentially hazardous food improperly thawed', 2),
#  (2010, 6, 'Handwash Facilities - Inaccessible, unavailable', 2),
#  (2010, 6, 'Evidence of rodents', 2),
#  (2010, 6, 'Unapproved Source', 1),
#  (2010, 6, 'Bent, swollen containers', 1),
#  (2010, 6, 'Contaminated equipment', 1),
#  (2010, 6, 'Cooling, Heating Procedures', 1),
#  (2010, 6, 'Food Cross Contamination', 1),
#  (2010, 6, 'Toxic Items- Improper Storage', 1),
#  (2010, 6, 'Other Operations - Ventilation', 1),
#  (2010, 6, 'Personnel w/infection restricted/excluded', 1),
#  (2010, 6, 'Evidence of insects', 1),
#  (2010, 6, 'Reheating Temp', 1),
#  (2010, 6, 'Barehand Contact with ready to eat food', 1),
#  (2010, 6, 'Other Operations - Premises', 1),
#  (2010, 6, 'Unapproved sewage and wastewater disposal', 1),
#  (2010, 6, 'Toilet room fixtures', 1),
#  (2010, 6, 'Toxic Items- Improper Labels', 1),
#  (2010, 6, 'Other Operations - Personal Items', 1),
#  (2010, 6, 'LACK OF REFRIGERATION', 1),
#  (2010, 6, 'Smoking, Eating, Drinking', 1)]

# %% [markdown]
# ## Bonus (10 points)
#
# We have seen a few simple techniques for normalizing data in class.  Choose a column or set of columns that might be redundant and normalize them out to another table:
#
# * Identify the columns to normalize in the source data table
# * Create one or more new tables to hold the normalized records
# * Extract data into the new tables
# * Re-insert the new foreign key references from the new table into the source table
